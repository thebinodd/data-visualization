# %%
import seaborn as sns

# %%
# Why Seaborn ?
# 1. Much Simpler and smaller code than matplotlib
# 2. More aesthetics
# 3. More Graphs included
# 4. More Popular

# Seaborn Roadmap

# 1. Types of Functions 
# - Figure Level
# - Axis Level

# 2. Main Classification

# a. Relational Plots -> Scatter / Line Plots
# b. Distribution Plots -> Histograms / kdeplot / ruglplot
# c. Categorical Plots -> BarPlots / CountPlots/ BoxPlots / Violin / Piechart
# d. Matrix Plot -> Heatmaps / ClusterMap
# e. Regression Plots
# f. Multiplots -> JointPlot / PairPlot
