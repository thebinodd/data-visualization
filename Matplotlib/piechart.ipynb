# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = [30 , 44 , 78 , 100 , 40 , 20]
plt.pie(data)
plt.show()

# %%
data = [70 , 90 , 50 , 66]
subjects = ["PHY" , "MTH" , "ENG" , "BIO"]
plt.pie(data , labels=subjects)
plt.show()

# %%
df = pd.read_csv("./datasets/gayle-175.csv")
df
# Out:
#           batsman  batsman_runs
# 0  AB de Villiers            31
# 1        CH Gayle           175
# 2       R Rampaul             0
# 3       SS Tiwary             2
# 4      TM Dilshan            33
# 5         V Kohli            11

# %%
plt.pie(df["batsman_runs"] ,
        labels = df["batsman"],
        colors = ["red" , "blue" , "green" , "pink" , "aqua"],
        autopct = "%0.1f%%" ,  #Show percentage
        explode = [0.1,0, 0,0,0,0] #Pop out some pie
       )
plt.show()
