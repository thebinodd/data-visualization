# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
children = [10 , 30 , 15 , 35 , 25]
colors = ["Red" , "Blue", "Aqua" , "Pink" , "Green"]
plt.bar(colors , children)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.barh(colors , children) #For Horizontal Bars
# Out:
# <BarContainer object of 5 artists>

# %%
df = pd.read_csv("./Datasets/batsman_season_record.csv")
df
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308

# %%
#For Individual Year
plt.bar(df["batsman"] , df["2016"])
# Out:
# <BarContainer object of 5 artists>

# %%
#For all years side by side 

#for 2015
plt.bar(np.arange(df.shape[0])-0.3 , df["2015"] , width=0.3) #shift this bar left side

#for 2016
plt.bar(np.arange(df.shape[0]) , df["2016"] , width = 0.3)

#for 2017
plt.bar(np.arange(df.shape[0]) + 0.3 , df["2017"] , width = 0.3) #shift this bar right side

#These three lines of code makes three barchart allined in one barchart area

#for ranaming x values
plt.xticks(np.arange(df.shape[0]) , df["batsman"])

#for clear show
plt.show()

# %%
#Stacked Barcharts
plt.bar(df["batsman"] , df["2017"] , label="2017") #For 2017 only
plt.bar(df["batsman"] , df["2016"] , bottom=df["2017"] , label="2016")
plt.bar(df["batsman"] , df["2015"] , bottom=(df["2017"]+df["2016"]), label="2015")#Place just above the 2017 and 2016 making stack
plt.legend() #Show labels of stacks
plt.show()

# %%
children = [10 , 30 , 15 , 35 , 25]
colors = ["RedRedRedRedRedRedRedRedRed" , "BlueBlueBlueBlueBlueBlueBlue", "AquaAquaAquaAquaAquaAquaAqua" , "PinkPinkPinkPinkPinkPinkPink" , "GreenGreenGreenGreenGreenGreen"]
plt.bar(colors , children ) #These long names make xticks overlaping
plt.xticks(rotation="vertical") #makes xticks vertical for better readibility
plt.show()
